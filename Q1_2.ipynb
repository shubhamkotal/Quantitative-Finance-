# %%
import pandas as pd
import numpy as np

data = pd.read_csv('MScFE 650 MLF GWP Data.csv', index_col='Date')
data.head()
# Out:
#               LUXXX  MSCI ARGENTINA  BLP ORIENTE MEDIO  MSCI AUSTRALIA  \
# Date
# 1-Jan-16   1390.716         2376.29          3525.9150         1068.79
# 8-Jan-16   1291.267         2260.85          3280.6683         1005.56
# 15-Jan-16  1257.086         2217.50          3118.2981          985.38
# 22-Jan-16  1254.167         2281.98          2935.0677          985.87
# 29-Jan-16  1298.240         2462.19          3134.0840         1005.56
#
#            MSCI AUSTRIA  MSCI BELGIUM  MSCI BRAZIL  MSCI CANADA  MSCI CHINA  \
# Date
# 1-Jan-16         106.70        105.38      1036.23      1663.27       59.47
# 8-Jan-16          97.66         99.35       952.01      1586.18       54.63
# 15-Jan-16         93.54         97.32       904.64      1541.08       51.54
# 22-Jan-16         95.79        100.73       879.17      1582.10       51.15
# 29-Jan-16         96.93        103.05       958.97      1638.84       52.13
#
# ...

# %%
from scipy import stats

#calculate 0% trimmed mean
mean = stats.trim_mean(data, 0)

#calculate 5% trimmed mean
mean_5p = stats.trim_mean(data, 0.05)

#calculate 50% trimmed mean
mean_50p = stats.trim_mean(data, 0.50)

print("Array of means of data set is: \n" + str(mean))
print("Array of means of 5% trimmed data set is: \n" + str(mean_5p))
print(data.describe())
# Out:
# Array of means of data set is:
# [ 1457.23190476  2526.6522619   3029.48297817  1183.94015873
#    127.41888889    91.2902381   1813.98916667  1970.82162698
#     76.78821429  8447.6577381    509.41305556   247.07940873
#    304.08464286  2502.4627381    121.92527778   145.76547619
#    143.52289683 14216.93115079  1187.46797619    55.79912698
#    943.75214286   647.38190476  4875.085        141.9881746
#    145.90444444  2720.59718254  1460.50781746   595.2077381
#   1618.22075476  1348.08813492   106.6734127  12385.38904762
#   1208.08146825  2013.18757937  2526.44853175]
# Array of means of 5% trimmed data set is:
# [ 1467.80062281  2510.84807018  3054.05824693  1183.27605263
#    127.51929825    92.04377193  1829.17298246  1977.83035088
#     76.86192982  8378.56302632   510.59675439   247.29142982
#    304.36464912  2519.50013158   122.29482456   145.74372807
#    143.89929825 14251.03065789  1190.83460526    55.86135965
# ...

# %%
# Assigning random weights of 0.3, 0.4 and 0.3 to each mean
# Choosing MSCI Singapore as consideration factor

Median_returns = 0.3*data['MSCI SINGAPORE'].describe(percentiles=[0.5])
Mean_returns = 0.3*data['MSCI SINGAPORE'].mean()
Mean_5p_returns = 0.4*(stats.trim_mean(data['MSCI SINGAPORE'], 0.05))

# %%
print('Returns on 5% trim mean series is :' + str(Mean_5p_returns))
print('Returns on Median series is :' + str(Median_returns['50%']))
print('Returns on Mean series is :' + str(Mean_returns))
# Out:
# Returns on Median series is :499.884
# Returns on Mean series is :485.4662264285715
# Returns on 5% trim mean series is :647.5355442105264
